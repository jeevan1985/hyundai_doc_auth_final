# %% [markdown]
# # 🧭 JK Image Similarity System — API & CLI Demonstration
#
# Professional, client-ready notebook demonstrating:
# - 🔐 Optional API security toggle (disable_api_security)
# - 👩‍💼 Admin workflows (build index, add image, TIF index build)
# - 👤 Regular user workflows (single search, batch search, TIF document search)
# - 🌐 API endpoints usage
# - 🖥️ CLI usage (find_sim_images.py)
#
# > Tip: This notebook assumes your API server is running (default http://127.0.0.1:5001/api/v1) and this notebook is executed from the project root.

# %% [markdown]
# ## ⚙️ Notebook Configuration
# Set the API base URL, API key (if security enabled), and choose whether to disable API security.
#
# - If `DISABLE_API_SECURITY` is true, the notebook will update `api_server/configs/api_config.yaml` to bypass all API security checks (API key/JWT/roles).
# - This is useful for quick testing or training, but DO NOT use in production.

# %%
import os, json, time, textwrap, subprocess, sys
from pathlib import Path
import requests
import yaml
from pprint import pprint

# --- Project root ---
PROJECT_ROOT = Path.cwd()
assert (PROJECT_ROOT / 'api_server').is_dir(), 'Please run this notebook from the project root.'

# --- API settings ---
API_BASE_URL = os.getenv('API_BASE_URL', 'http://127.0.0.1:5001/api/v1')
API_KEY = os.getenv('IMAGE_SIM_API_KEY', '')  # Leave blank if security disabled

# --- Security toggle for API ---
DISABLE_API_SECURITY = True  # Set True to bypass API security

# --- Example paths ---
# Adjust these to point to valid local files/folders before running certain cells.
DB_IMAGE_FOLDER = str(PROJECT_ROOT / 'instance' / 'database_images')
SINGLE_QUERY_IMAGE = str(PROJECT_ROOT / 'data_real' / 'N2024030602067THA00100001_12.tif')  # Put an image here to test
SERVER_BATCH_QUERY_FOLDER = str(PROJECT_ROOT / 'data_real')    # Folder of images on server
SERVER_TIF_FOLDER = str(PROJECT_ROOT / 'data_real')                           # Folder of .tif files on server
LOCAL_TIF_FILES = [                                                                    # Local .tif files for client-side upload
    str(PROJECT_ROOT / 'instance' / 'tifs' / 'sample1.tif'),
    str(PROJECT_ROOT / 'instance' / 'tifs' / 'sample2.tif'),
]

# %%
print (API_KEY)
# Out:
# jk_pub_9bad7429_5i_DHKceVfoGAAymirT7TBoUQz1C79s_wW_W3JN_5BI

# %% [markdown]
# ### 🛡️ Apply API Security Toggle (disable_api_security)
# Updates `api_server/configs/api_config.yaml` to enable/disable API security.
#
# - When enabled (true), the API will skip all authentication and role checks.
# - This change is read on each request by the server; no restart is typically necessary.

# %%
def set_disable_api_security(flag: bool, also_set_nested=True):
    cfg_path = PROJECT_ROOT / 'api_server' / 'configs' / 'api_config.yaml'
    if not cfg_path.is_file():
        raise FileNotFoundError(f'Config file not found: {cfg_path}')
    with cfg_path.open('r', encoding='utf-8') as f:
        data = yaml.safe_load(f) or {}
    data['disable_api_security'] = bool(flag)
    if also_set_nested:
        sec = data.get('security') or {}
        sec['disable_api_security'] = bool(flag)
        data['security'] = sec
    with cfg_path.open('w', encoding='utf-8') as f:
        yaml.safe_dump(data, f, sort_keys=False)
    print(f'Updated disable_api_security to {flag} in {cfg_path}')

set_disable_api_security(DISABLE_API_SECURITY)
# Out:
# Updated disable_api_security to True in d:\jk\jk_SMART_VISION\TEST_SRC\TifDoc_nd_image_similarity_search\api_server\configs\api_config.yaml

# %% [markdown]
# ## 🚧 Temporary Per-Request Security Bypass (Until Server Fix/Restart)
#
# If you encounter 401 Unauthorized due to missing Authorization while security is meant to be disabled, you can bypass authentication per request using a special header:
# - Header: `X-DISABLE-API-SECURITY: true`
#
# Use the cells below to quickly test API endpoints without tokens while a server-side update or restart is pending.
#
# ⚠️ Use for local testing only. Do not use in production.

# %%
import requests, json
BYPASS_HEADERS = {}
if API_KEY:
    BYPASS_HEADERS['Authorization'] = f'Bearer {API_KEY}'
if DISABLE_API_SECURITY:
    BYPASS_HEADERS['X-DISABLE-API-SECURITY'] = 'true'
print("Using BYPASS_HEADERS:", BYPASS_HEADERS)
# Out:
# Using BYPASS_HEADERS: {'Authorization': 'Bearer jk_pub_9bad7429_5i_DHKceVfoGAAymirT7TBoUQz1C79s_wW_W3JN_5BI', 'X-DISABLE-API-SECURITY': 'true'}

# %% [markdown]
# ### 🩺 Status Check with Bypass Header — GET /status

# %%
url = f"{API_BASE_URL.rstrip('/')}/status"
resp = requests.get(url, headers=BYPASS_HEADERS, timeout=30)
print(f"GET {url} -> {resp.status_code}")
try:
    print(json.dumps(resp.json(), indent=2))
except Exception:
    print(resp.text)
# Out:
# GET http://127.0.0.1:5001/api/v1/status -> 200
# {
#   "active_model": "resnet",
#   "active_vector_db": "faiss",
#   "api_status": "operational",
#   "feature_extractor_status": "ok (model: 'resnet', dim: 2048)",
#   "system_name": "JK Image Similarity System API",
#   "timestamp": "2025-08-22T14:17:19.440081Z",
#   "vector_db_status": "not_ready (items: 0)"
# }

# %% [markdown]
# ### 📝 Note
# - The above cells call requests directly and do not rely on the helper functions.
# - Once the server-side fix is applied and reloaded, you can remove the BYPASS_HEADERS argument and use the standard helpers again.

# %% [markdown]
# ### 🔎 JSON Search with Bypass Header — POST /search

# %%
from pathlib import Path
from base64 import b64encode
url = f"{API_BASE_URL.rstrip('/')}/search"
payload = {
    "config_overrides": {
        "search_task": {"top_k": 5},
        "action": "search"
    }
}
# Provide a query source: prefer server-side batch folder, else single image path, else optional base64
if Path(SERVER_BATCH_QUERY_FOLDER).is_dir():
    payload["batch_query_image_folder_path"] = SERVER_BATCH_QUERY_FOLDER
elif Path(SINGLE_QUERY_IMAGE).is_file():
    ## Directly using the image path of image available in server
    # payload["query_image_path"] = SINGLE_QUERY_IMAGE
    ## Alternatively, send as base64 of the real image instead of server path (can be from client side too):
    with open(SINGLE_QUERY_IMAGE, "rb") as f:
        payload["image_base64"] = b64encode(f.read()).decode("ascii")
else:
    print(f"⚠️ No valid SERVER_BATCH_QUERY_FOLDER or SINGLE_QUERY_IMAGE found. Update paths before running.")
resp = requests.post(url, json=payload, headers=BYPASS_HEADERS, timeout=120)
print(f"POST {url} -> {resp.status_code}")
try:
    print(json.dumps(resp.json(), indent=2))
except Exception:
    print(resp.text)
# Out:
# POST http://127.0.0.1:5001/api/v1/search -> 200
# {
#   "batch_search_gallery_path_segment": "admin/api_runs/api_run_fbb18e055a16",
#   "config_was_modified": false,
#   "exit_code": 0,
#   "fallback_to_bruteforce_message": null,
#   "general_search_summary_msg": "Batch search complete. Results in D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16",
#   "index_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_faiss_indices\\api_faiss_collection_resnet_flat.index",
#   "indexed_image_count": 102,
#   "last_search_was_batch": true,
#   "message": "Batch search completed. 3 successful, 0 failed. Results also saved to PostgreSQL.",
#   "missing_files_count": 0,
#   "model_name_used": "resnet",
#   "overall_results_output_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16",
#   "search_method_used": "faiss",
#   "search_operation_summary": {
#     "aggregated_search_statistics": {
#       "total_missing_result_files": 0
#     },
#     "failed_searches": [],
#     "successful_searches": [
#       {
#         "performance_metrics": {
#           "total_search_operation_time_seconds": 0.12625861167907715
#         },
#         "query_image_details": {
#           "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602067THA00100001_12.tif\\_query_image_source\\N2024030602067THA00100001_12.tif",
#           "metadata": {
#             "dimensions_str": "1652 x 2336",
#             "size_bytes": 1030035
#           },
#           "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\data_real\\N2024030602067THA00100001_12.tif"
#         },
#         "results": [
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602067THA00100001_12.tif\\rank_001_N2024030602067THA00100001_12.tif",
#             "metadata": {
#               "dimensions_str": "1652 x 2336",
#               "size_bytes": 1030035
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_12.tif",
#             "rank": 1,
#             "similarity_score": 1.0
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602067THA00100001_12.tif\\rank_002_N2024030602067THA00100001_12_page1_photo0.jpg",
#             "metadata": {
#               "dimensions_str": "1309 x 864",
#               "size_bytes": 268469
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_12_page1_photo0.jpg",
#             "rank": 2,
#             "similarity_score": 0.4988870620727539
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602067THA00100001_12.tif\\rank_003_N2024030602086THA00100001_12_page1_photo14.jpg",
#             "metadata": {
#               "dimensions_str": "198 x 156",
#               "size_bytes": 6268
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo14.jpg",
#             "rank": 3,
#             "similarity_score": 0.4319976568222046
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602067THA00100001_12.tif\\rank_004_N2024030602086THA00100001_12_page1_photo10.jpg",
#             "metadata": {
#               "dimensions_str": "165 x 384",
#               "size_bytes": 11661
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo10.jpg",
#             "rank": 4,
#             "similarity_score": 0.42367124557495117
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602067THA00100001_12.tif\\rank_005_N2024030602086THA00100001_12_page1_photo12.jpg",
#             "metadata": {
#               "dimensions_str": "216 x 170",
#               "size_bytes": 8042
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo12.jpg",
#             "rank": 5,
#             "similarity_score": 0.40960878133773804
#           }
#         ],
#         "results_summary": {
#           "number_of_similar_images_found": 5,
#           "search_statistics": {
#             "missing_result_files": 0
#           }
#         },
#         "search_parameters_overview": {
#           "feature_dimension_used": 2048,
#           "model_name_used": "resnet",
#           "search_method_used": "FaissIndex",
#           "top_k_requested": 5
#         },
#         "search_run_timestamp": "2025-08-22T14:20:40.114149"
#       },
#       {
#         "performance_metrics": {
#           "total_search_operation_time_seconds": 0.10811853408813477
#         },
#         "query_image_details": {
#           "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602067THA00100001_13.tif\\_query_image_source\\N2024030602067THA00100001_13.tif",
#           "metadata": {
#             "dimensions_str": "1652 x 2336",
#             "size_bytes": 875393
#           },
#           "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\data_real\\N2024030602067THA00100001_13.tif"
#         },
#         "results": [
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602067THA00100001_13.tif\\rank_001_N2024030602067THA00100001_13_page1_photo1.jpg",
#             "metadata": {
#               "dimensions_str": "1309 x 864",
#               "size_bytes": 184510
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_13_page1_photo1.jpg",
#             "rank": 1,
#             "similarity_score": 0.5818923115730286
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602067THA00100001_13.tif\\rank_002_N2024030602067THA00100001_12.tif",
#             "metadata": {
#               "dimensions_str": "1652 x 2336",
#               "size_bytes": 1030035
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_12.tif",
#             "rank": 2,
#             "similarity_score": 0.5664472877979279
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602067THA00100001_13.tif\\rank_003_N2024030602067THA00100001_13_page1_photo0.jpg",
#             "metadata": {
#               "dimensions_str": "1309 x 864",
#               "size_bytes": 186729
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_13_page1_photo0.jpg",
#             "rank": 3,
#             "similarity_score": 0.4469359517097473
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602067THA00100001_13.tif\\rank_004_N2024030602110THA00100001_13_page1_photo1.jpg",
#             "metadata": {
#               "dimensions_str": "1309 x 864",
#               "size_bytes": 136212
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602110THA00100001_13_page1_photo1.jpg",
#             "rank": 4,
#             "similarity_score": 0.40287989377975464
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602067THA00100001_13.tif\\rank_005_N2024030602077THA00100001_13_page1_photo1.jpg",
#             "metadata": {
#               "dimensions_str": "1309 x 864",
#               "size_bytes": 149766
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602077THA00100001_13_page1_photo1.jpg",
#             "rank": 5,
#             "similarity_score": 0.3847198486328125
#           }
#         ],
#         "results_summary": {
#           "number_of_similar_images_found": 5,
#           "search_statistics": {
#             "missing_result_files": 0
#           }
#         },
#         "search_parameters_overview": {
#           "feature_dimension_used": 2048,
#           "model_name_used": "resnet",
#           "search_method_used": "FaissIndex",
#           "top_k_requested": 5
#         },
#         "search_run_timestamp": "2025-08-22T14:20:40.333275"
#       },
#       {
#         "performance_metrics": {
#           "total_search_operation_time_seconds": 0.11218690872192383
#         },
#         "query_image_details": {
#           "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602077THA00100001_12.tif\\_query_image_source\\N2024030602077THA00100001_12.tif",
#           "metadata": {
#             "dimensions_str": "1652 x 2336",
#             "size_bytes": 793751
#           },
#           "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\data_real\\N2024030602077THA00100001_12.tif"
#         },
#         "results": [
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602077THA00100001_12.tif\\rank_001_N2024030602110THA00100001_12_page1_photo6.jpg",
#             "metadata": {
#               "dimensions_str": "462 x 500",
#               "size_bytes": 45647
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602110THA00100001_12_page1_photo6.jpg",
#             "rank": 1,
#             "similarity_score": 0.5204832255840302
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602077THA00100001_12.tif\\rank_002_N2024030602086THA00100001_12_page1_photo8.jpg",
#             "metadata": {
#               "dimensions_str": "741 x 730",
#               "size_bytes": 121453
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo8.jpg",
#             "rank": 2,
#             "similarity_score": 0.5065967440605164
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602077THA00100001_12.tif\\rank_003_N2024030602110THA00100001_12_page1_photo3.jpg",
#             "metadata": {
#               "dimensions_str": "545 x 863",
#               "size_bytes": 104811
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602110THA00100001_12_page1_photo3.jpg",
#             "rank": 3,
#             "similarity_score": 0.49728870391845703
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602077THA00100001_12.tif\\rank_004_N2024030602086THA00100001_12_page1_photo3.jpg",
#             "metadata": {
#               "dimensions_str": "738 x 330",
#               "size_bytes": 56867
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo3.jpg",
#             "rank": 4,
#             "similarity_score": 0.48426640033721924
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_fbb18e055a16\\N2024030602077THA00100001_12.tif\\rank_005_N2024030602110THA00100001_12_page1_photo2.jpg",
#             "metadata": {
#               "dimensions_str": "202 x 241",
#               "size_bytes": 9058
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602110THA00100001_12_page1_photo2.jpg",
#             "rank": 5,
#             "similarity_score": 0.4531239867210388
#           }
#         ],
#         "results_summary": {
#           "number_of_similar_images_found": 5,
#           "search_statistics": {
#             "missing_result_files": 0
#           }
#         },
#         "search_parameters_overview": {
#           "feature_dimension_used": 2048,
#           "model_name_used": "resnet",
#           "search_method_used": "FaissIndex",
#           "top_k_requested": 5
#         },
#         "search_run_timestamp": "2025-08-22T14:20:40.561683"
#       }
#     ],
#     "total_queries_attempted": 3,
#     "total_queries_failed": 0,
#     "total_queries_successful": 3
#   },
#   "status": "success"
# }

# %% [markdown]
# ### 🖼️ Multipart Search with Bypass Header — POST /search (multipart/form-data)
# Uploads a single image from SINGLE_QUERY_IMAGE.

# %%
from pathlib import Path
if Path(SINGLE_QUERY_IMAGE).is_file():
    url = f"{API_BASE_URL.rstrip('/')}/search"
    fobj = open(SINGLE_QUERY_IMAGE, "rb")
    
    try:
        files = {"image": (Path(SINGLE_QUERY_IMAGE).name, fobj, "application/octet-stream")}
        data = {"config_overrides": json.dumps({"search_task": {"top_k": 5}})}
        resp = requests.post(url, headers=BYPASS_HEADERS, files=files, data=data, timeout=120)
        print(f"POST {url} -> {resp.status_code}")
        try:
            print(json.dumps(resp.json(), indent=2))
        except Exception:
            print(resp.text)
    finally:
        try:
            fobj.close()
        except Exception:
            pass
else:
    print(f"⚠️ SINGLE_QUERY_IMAGE not found: {SINGLE_QUERY_IMAGE}")
# Out:
# POST http://127.0.0.1:5001/api/v1/search -> 200
# {
#   "config_was_modified": false,
#   "exit_code": 0,
#   "fallback_to_bruteforce_message": null,
#   "index_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_faiss_indices\\api_faiss_collection_resnet_flat.index",
#   "indexed_image_count": 101,
#   "message": "Single image search completed successfully. Results also saved to PostgreSQL.",
#   "missing_files_count": 0,
#   "model_name_used": "resnet",
#   "overall_results_output_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_e21bfd73ea4d",
#   "search_method_used": "faiss",
#   "search_operation_summary": {
#     "performance_metrics": {
#       "total_search_operation_time_seconds": 0.12993121147155762
#     },
#     "query_image_details": {
#       "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_e21bfd73ea4d\\_query_image_source\\0352ff83952a4e0692bfb61ae8b8d6a6_N2024030602067THA00100001_12.tif",
#       "metadata": {
#         "dimensions_str": "1652 x 2336",
#         "size_bytes": 1030035
#       },
#       "original_path": "C:\\Users\\jeeb\\AppData\\Local\\Temp\\api_image_sim_uploads\\0352ff83952a4e0692bfb61ae8b8d6a6_N2024030602067THA00100001_12.tif",
#       "web_path": "admin/api_runs/api_run_e21bfd73ea4d/_query_image_source/0352ff83952a4e0692bfb61ae8b8d6a6_N2024030602067THA00100001_12.tif"
#     },
#     "results": [
#       {
#         "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_e21bfd73ea4d\\rank_001_N2024030602067THA00100001_12_page1_photo0.jpg",
#         "metadata": {
#           "dimensions_str": "1309 x 864",
#           "size_bytes": 268469
#         },
#         "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_12_page1_photo0.jpg",
#         "rank": 1,
#         "similarity_score": 0.4988870620727539,
#         "web_path": "admin/api_runs/api_run_e21bfd73ea4d/rank_001_N2024030602067THA00100001_12_page1_photo0.jpg"
#       },
#       {
#         "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_e21bfd73ea4d\\rank_002_N2024030602086THA00100001_12_page1_photo14.jpg",
#         "metadata": {
#           "dimensions_str": "198 x 156",
#           "size_bytes": 6268
#         },
#         "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo14.jpg",
#         "rank": 2,
#         "similarity_score": 0.4319976568222046,
#         "web_path": "admin/api_runs/api_run_e21bfd73ea4d/rank_002_N2024030602086THA00100001_12_page1_photo14.jpg"
#       },
#       {
#         "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_e21bfd73ea4d\\rank_003_N2024030602086THA00100001_12_page1_photo10.jpg",
#         "metadata": {
#           "dimensions_str": "165 x 384",
#           "size_bytes": 11661
#         },
#         "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo10.jpg",
#         "rank": 3,
#         "similarity_score": 0.42367124557495117,
#         "web_path": "admin/api_runs/api_run_e21bfd73ea4d/rank_003_N2024030602086THA00100001_12_page1_photo10.jpg"
#       },
#       {
#         "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_e21bfd73ea4d\\rank_004_N2024030602086THA00100001_12_page1_photo12.jpg",
#         "metadata": {
#           "dimensions_str": "216 x 170",
#           "size_bytes": 8042
#         },
#         "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo12.jpg",
#         "rank": 4,
#         "similarity_score": 0.40960878133773804,
#         "web_path": "admin/api_runs/api_run_e21bfd73ea4d/rank_004_N2024030602086THA00100001_12_page1_photo12.jpg"
#       },
#       {
#         "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_e21bfd73ea4d\\rank_005_N2024030602067THA00100001_12_page1_photo1.jpg",
#         "metadata": {
#           "dimensions_str": "1309 x 864",
#           "size_bytes": 139832
#         },
#         "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_12_page1_photo1.jpg",
#         "rank": 5,
#         "similarity_score": 0.4044302701950073,
#         "web_path": "admin/api_runs/api_run_e21bfd73ea4d/rank_005_N2024030602067THA00100001_12_page1_photo1.jpg"
#       }
#     ],
#     "results_summary": {
#       "number_of_similar_images_found": 5,
#       "search_statistics": {
#         "missing_result_files": 0
#       }
#     },
#     "search_parameters_overview": {
#       "feature_dimension_used": 2048,
#       "model_name_used": "resnet",
#       "search_method_used": "FaissIndex",
#       "top_k_requested": 5
#     },
#     "search_run_timestamp": "2025-08-22T14:17:25.181965"
#   },
#   "status": "success"
# }

# %% [markdown]
# ### 📝 Note
# - The above cells call requests directly and do not rely on the helper functions.
# - Once the server-side fix is applied and reloaded, you can remove the BYPASS_HEADERS argument and use the standard helpers again.

# %% [markdown]
# ### 🔧 Helper: API Request Wrapper
# Handles headers automatically depending on security mode and pretty-prints JSON responses.

# %%
def api_headers():
    headers = {}
    if API_KEY:
        headers['Authorization'] = f'Bearer {API_KEY}'
    elif not DISABLE_API_SECURITY:
        print('Warning: API_KEY is empty and security is enabled.')
    if DISABLE_API_SECURITY:
        headers['X-DISABLE-API-SECURITY'] = 'true'
    return headers

def call_api(method: str, path: str, **kwargs):
    url = f"{API_BASE_URL.rstrip('/')}/{path.lstrip('/')}"
    hdrs = kwargs.pop('headers', {})
    hdrs.update(api_headers())
    resp = requests.request(method.upper(), url, headers=hdrs, **kwargs)
    try:
        resp.raise_for_status()
        data = resp.json()
        print(f'✅ {method.upper()} {url} -> {resp.status_code}')
        print(json.dumps(data, indent=2))
        return data
    except requests.exceptions.HTTPError as e:
        print(f'❌ {method.upper()} {url} -> {resp.status_code}')
        try:
            print(json.dumps(resp.json(), indent=2))
        except Exception:
            print(resp.text)
        raise

def exists_file(p):
    try:
        return Path(p).is_file()
    except Exception:
        return False

def exists_dir(p):
    try:
        return Path(p).is_dir()
    except Exception:
        return False

# %% [markdown]
# ---
# # 👩‍💼 Admin Usage
# > Requires admin role when security is enabled (or disabled security).

# %% [markdown]
# ### 🩺 API Status

# %%
_ = call_api('GET', 'status')
# Out:
# ✅ GET http://127.0.0.1:5001/api/v1/status -> 200
# {
#   "active_model": "resnet",
#   "active_vector_db": "faiss",
#   "api_status": "operational",
#   "feature_extractor_status": "ok (model: 'resnet', dim: 2048)",
#   "system_name": "JK Image Similarity System API",
#   "timestamp": "2025-08-22T14:17:26.627259Z",
#   "vector_db_status": "not_ready (items: 0)"
# }

# %% [markdown]
# ### 🏗️ Build/Update Index (Images) — POST /build_index
# Uses API configuration merged with any overrides below.

# %%
payload = {
    'config_overrides': {
        'indexing_task': {
            'image_folder_to_index': DB_IMAGE_FOLDER,
            'force_rebuild_index': False
        },
        'vector_database': {'provider': 'faiss'}
    }
}
_ = call_api('POST', 'build_index', json=payload)
# Out:
# ✅ POST http://127.0.0.1:5001/api/v1/build_index -> 200
# {
#   "config_was_modified": false,
#   "exit_code": 0,
#   "index_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_faiss_indices\\api_faiss_collection_resnet_flat.index",
#   "indexed_image_count": 101,
#   "message": "Index built successfully. Total items: 101.",
#   "model_name_used": "resnet",
#   "status": "success"
# }

# %% [markdown]
# ### 🧩 Build Index from TIFs — POST /build_index_from_tifs
# Extracts photos from TIF docs and builds/upgrades the image index.

# %%
payload = {
    'config_overrides': {
        'indexing_task': {
            'input_tif_folder_for_indexing': SERVER_TIF_FOLDER,
            'image_folder_to_index': DB_IMAGE_FOLDER
        }
    }
}
_ = call_api('POST', 'build_index_from_tifs', json=payload)
# Out:
# ✅ POST http://127.0.0.1:5001/api/v1/build_index_from_tifs -> 200
# {
#   "exit_code": 0,
#   "extracted_images_count": 6,
#   "index_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_faiss_indices\\api_faiss_collection_resnet_flat.index",
#   "indexed_image_count": 101,
#   "message": "TIF extraction complete. Extracted images: 6. Index built successfully. Total items: 101.",
#   "status": "success"
# }

# %% [markdown]
# ### ➕ Add Image to Database — POST /add_image
# Uploads one image to the database folder used for indexing.

# %%
if exists_file(SINGLE_QUERY_IMAGE):
    with open(SINGLE_QUERY_IMAGE, 'rb') as f:
        files = {'image': (Path(SINGLE_QUERY_IMAGE).name, f, 'application/octet-stream')}
        _ = call_api('POST', 'add_image', files=files)
else:
    print(f'⚠️ SINGLE_QUERY_IMAGE not found: {SINGLE_QUERY_IMAGE}. Skipping upload demo.')
# Out:
# ✅ POST http://127.0.0.1:5001/api/v1/add_image -> 201
# {
#   "filename_saved": "N2024030602067THA00100001_12.tif",
#   "message": "Image added successfully. It is now available for the next index build.",
#   "saved_path_absolute": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_12.tif"
# }

# %% [markdown]
# ---
# # 👤 Regular User Usage
# > Works without admin rights if security disabled or with valid API key when enabled.

# %% [markdown]
# ### 🔎 Single Image Search — POST /search (multipart/form-data)
# Uploads a single image and returns similar images.

# %%
if exists_file(SINGLE_QUERY_IMAGE):
    with open(SINGLE_QUERY_IMAGE, 'rb') as f:
        files = {'image': (Path(SINGLE_QUERY_IMAGE).name, f, 'application/octet-stream')}
        data = {'config_overrides': json.dumps({'search_task': {'top_k': 5}})}
        _ = call_api('POST', 'search', files=files, data=data)
else:
    print(f'⚠️ SINGLE_QUERY_IMAGE not found: {SINGLE_QUERY_IMAGE}. Skipping single search demo.')
# Out:
# ✅ POST http://127.0.0.1:5001/api/v1/search -> 200
# {
#   "config_was_modified": false,
#   "exit_code": 0,
#   "fallback_to_bruteforce_message": null,
#   "index_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_faiss_indices\\api_faiss_collection_resnet_flat.index",
#   "indexed_image_count": 102,
#   "message": "Single image search completed successfully. Results also saved to PostgreSQL.",
#   "missing_files_count": 0,
#   "model_name_used": "resnet",
#   "overall_results_output_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_163941ee7296",
#   "search_method_used": "faiss",
#   "search_operation_summary": {
#     "performance_metrics": {
#       "total_search_operation_time_seconds": 0.09908246994018555
#     },
#     "query_image_details": {
#       "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_163941ee7296\\_query_image_source\\c6d6874367954a2a830e28a117db1f51_N2024030602067THA00100001_12.tif",
#       "metadata": {
#         "dimensions_str": "1652 x 2336",
#         "size_bytes": 1030035
#       },
#       "original_path": "C:\\Users\\jeeb\\AppData\\Local\\Temp\\api_image_sim_uploads\\c6d6874367954a2a830e28a117db1f51_N2024030602067THA00100001_12.tif",
#       "web_path": "admin/api_runs/api_run_163941ee7296/_query_image_source/c6d6874367954a2a830e28a117db1f51_N2024030602067THA00100001_12.tif"
#     },
#     "results": [
#       {
#         "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_163941ee7296\\rank_001_N2024030602067THA00100001_12.tif",
#         "metadata": {
#           "dimensions_str": "1652 x 2336",
#           "size_bytes": 1030035
#         },
#         "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_12.tif",
#         "rank": 1,
#         "similarity_score": 1.0,
#         "web_path": "admin/api_runs/api_run_163941ee7296/rank_001_N2024030602067THA00100001_12.tif"
#       },
#       {
#         "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_163941ee7296\\rank_002_N2024030602067THA00100001_12_page1_photo0.jpg",
#         "metadata": {
#           "dimensions_str": "1309 x 864",
#           "size_bytes": 268469
#         },
#         "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_12_page1_photo0.jpg",
#         "rank": 2,
#         "similarity_score": 0.4988870620727539,
#         "web_path": "admin/api_runs/api_run_163941ee7296/rank_002_N2024030602067THA00100001_12_page1_photo0.jpg"
#       },
#       {
#         "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_163941ee7296\\rank_003_N2024030602086THA00100001_12_page1_photo14.jpg",
#         "metadata": {
#           "dimensions_str": "198 x 156",
#           "size_bytes": 6268
#         },
#         "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo14.jpg",
#         "rank": 3,
#         "similarity_score": 0.4319976568222046,
#         "web_path": "admin/api_runs/api_run_163941ee7296/rank_003_N2024030602086THA00100001_12_page1_photo14.jpg"
#       },
#       {
#         "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_163941ee7296\\rank_004_N2024030602086THA00100001_12_page1_photo10.jpg",
#         "metadata": {
#           "dimensions_str": "165 x 384",
#           "size_bytes": 11661
#         },
#         "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo10.jpg",
#         "rank": 4,
#         "similarity_score": 0.42367124557495117,
#         "web_path": "admin/api_runs/api_run_163941ee7296/rank_004_N2024030602086THA00100001_12_page1_photo10.jpg"
#       },
#       {
#         "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_163941ee7296\\rank_005_N2024030602086THA00100001_12_page1_photo12.jpg",
#         "metadata": {
#           "dimensions_str": "216 x 170",
#           "size_bytes": 8042
#         },
#         "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo12.jpg",
#         "rank": 5,
#         "similarity_score": 0.40960878133773804,
#         "web_path": "admin/api_runs/api_run_163941ee7296/rank_005_N2024030602086THA00100001_12_page1_photo12.jpg"
#       }
#     ],
#     "results_summary": {
#       "number_of_similar_images_found": 5,
#       "search_statistics": {
#         "missing_result_files": 0
#       }
#     },
#     "search_parameters_overview": {
#       "feature_dimension_used": 2048,
#       "model_name_used": "resnet",
#       "search_method_used": "FaissIndex",
#       "top_k_requested": 5
#     },
#     "search_run_timestamp": "2025-08-22T14:17:41.587737"
#   },
#   "status": "success"
# }

# %% [markdown]
# ### 📂 Batch Image Search (Server-side Folder) — POST /search (JSON)
# Provide a folder path on the server to process batch queries.

# %%
if exists_dir(SERVER_BATCH_QUERY_FOLDER):
    payload = {
        'config_overrides': {
            'search_task': {
                'batch_query_image_folder_path': SERVER_BATCH_QUERY_FOLDER,
                'top_k': 5
            }
        }
    }
    _ = call_api('POST', 'search', json=payload)
else:
    print(f'⚠️ SERVER_BATCH_QUERY_FOLDER not found: {SERVER_BATCH_QUERY_FOLDER}. Skipping batch search demo.')
# Out:
# ✅ POST http://127.0.0.1:5001/api/v1/search -> 200
# {
#   "batch_search_gallery_path_segment": "admin/api_runs/api_run_07d0a92bda21",
#   "config_was_modified": false,
#   "exit_code": 0,
#   "fallback_to_bruteforce_message": null,
#   "general_search_summary_msg": "Batch search complete. Results in D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21",
#   "index_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_faiss_indices\\api_faiss_collection_resnet_flat.index",
#   "indexed_image_count": 102,
#   "last_search_was_batch": true,
#   "message": "Batch search completed. 3 successful, 0 failed. Results also saved to PostgreSQL.",
#   "missing_files_count": 0,
#   "model_name_used": "resnet",
#   "overall_results_output_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21",
#   "search_method_used": "faiss",
#   "search_operation_summary": {
#     "aggregated_search_statistics": {
#       "total_missing_result_files": 0
#     },
#     "failed_searches": [],
#     "successful_searches": [
#       {
#         "performance_metrics": {
#           "total_search_operation_time_seconds": 0.11235523223876953
#         },
#         "query_image_details": {
#           "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602067THA00100001_12.tif\\_query_image_source\\N2024030602067THA00100001_12.tif",
#           "metadata": {
#             "dimensions_str": "1652 x 2336",
#             "size_bytes": 1030035
#           },
#           "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\data_real\\N2024030602067THA00100001_12.tif"
#         },
#         "results": [
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602067THA00100001_12.tif\\rank_001_N2024030602067THA00100001_12.tif",
#             "metadata": {
#               "dimensions_str": "1652 x 2336",
#               "size_bytes": 1030035
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_12.tif",
#             "rank": 1,
#             "similarity_score": 1.0
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602067THA00100001_12.tif\\rank_002_N2024030602067THA00100001_12_page1_photo0.jpg",
#             "metadata": {
#               "dimensions_str": "1309 x 864",
#               "size_bytes": 268469
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_12_page1_photo0.jpg",
#             "rank": 2,
#             "similarity_score": 0.4988870620727539
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602067THA00100001_12.tif\\rank_003_N2024030602086THA00100001_12_page1_photo14.jpg",
#             "metadata": {
#               "dimensions_str": "198 x 156",
#               "size_bytes": 6268
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo14.jpg",
#             "rank": 3,
#             "similarity_score": 0.4319976568222046
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602067THA00100001_12.tif\\rank_004_N2024030602086THA00100001_12_page1_photo10.jpg",
#             "metadata": {
#               "dimensions_str": "165 x 384",
#               "size_bytes": 11661
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo10.jpg",
#             "rank": 4,
#             "similarity_score": 0.42367124557495117
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602067THA00100001_12.tif\\rank_005_N2024030602086THA00100001_12_page1_photo12.jpg",
#             "metadata": {
#               "dimensions_str": "216 x 170",
#               "size_bytes": 8042
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo12.jpg",
#             "rank": 5,
#             "similarity_score": 0.40960878133773804
#           }
#         ],
#         "results_summary": {
#           "number_of_similar_images_found": 5,
#           "search_statistics": {
#             "missing_result_files": 0
#           }
#         },
#         "search_parameters_overview": {
#           "feature_dimension_used": 2048,
#           "model_name_used": "resnet",
#           "search_method_used": "FaissIndex",
#           "top_k_requested": 5
#         },
#         "search_run_timestamp": "2025-08-22T14:17:43.902010"
#       },
#       {
#         "performance_metrics": {
#           "total_search_operation_time_seconds": 0.12895560264587402
#         },
#         "query_image_details": {
#           "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602067THA00100001_13.tif\\_query_image_source\\N2024030602067THA00100001_13.tif",
#           "metadata": {
#             "dimensions_str": "1652 x 2336",
#             "size_bytes": 875393
#           },
#           "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\data_real\\N2024030602067THA00100001_13.tif"
#         },
#         "results": [
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602067THA00100001_13.tif\\rank_001_N2024030602067THA00100001_13_page1_photo1.jpg",
#             "metadata": {
#               "dimensions_str": "1309 x 864",
#               "size_bytes": 184510
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_13_page1_photo1.jpg",
#             "rank": 1,
#             "similarity_score": 0.5818923115730286
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602067THA00100001_13.tif\\rank_002_N2024030602067THA00100001_12.tif",
#             "metadata": {
#               "dimensions_str": "1652 x 2336",
#               "size_bytes": 1030035
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_12.tif",
#             "rank": 2,
#             "similarity_score": 0.5664472877979279
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602067THA00100001_13.tif\\rank_003_N2024030602067THA00100001_13_page1_photo0.jpg",
#             "metadata": {
#               "dimensions_str": "1309 x 864",
#               "size_bytes": 186729
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_13_page1_photo0.jpg",
#             "rank": 3,
#             "similarity_score": 0.4469359517097473
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602067THA00100001_13.tif\\rank_004_N2024030602110THA00100001_13_page1_photo1.jpg",
#             "metadata": {
#               "dimensions_str": "1309 x 864",
#               "size_bytes": 136212
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602110THA00100001_13_page1_photo1.jpg",
#             "rank": 4,
#             "similarity_score": 0.40287989377975464
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602067THA00100001_13.tif\\rank_005_N2024030602077THA00100001_13_page1_photo1.jpg",
#             "metadata": {
#               "dimensions_str": "1309 x 864",
#               "size_bytes": 149766
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602077THA00100001_13_page1_photo1.jpg",
#             "rank": 5,
#             "similarity_score": 0.3847198486328125
#           }
#         ],
#         "results_summary": {
#           "number_of_similar_images_found": 5,
#           "search_statistics": {
#             "missing_result_files": 0
#           }
#         },
#         "search_parameters_overview": {
#           "feature_dimension_used": 2048,
#           "model_name_used": "resnet",
#           "search_method_used": "FaissIndex",
#           "top_k_requested": 5
#         },
#         "search_run_timestamp": "2025-08-22T14:17:44.112591"
#       },
#       {
#         "performance_metrics": {
#           "total_search_operation_time_seconds": 0.11656332015991211
#         },
#         "query_image_details": {
#           "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602077THA00100001_12.tif\\_query_image_source\\N2024030602077THA00100001_12.tif",
#           "metadata": {
#             "dimensions_str": "1652 x 2336",
#             "size_bytes": 793751
#           },
#           "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\data_real\\N2024030602077THA00100001_12.tif"
#         },
#         "results": [
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602077THA00100001_12.tif\\rank_001_N2024030602110THA00100001_12_page1_photo6.jpg",
#             "metadata": {
#               "dimensions_str": "462 x 500",
#               "size_bytes": 45647
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602110THA00100001_12_page1_photo6.jpg",
#             "rank": 1,
#             "similarity_score": 0.5204832255840302
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602077THA00100001_12.tif\\rank_002_N2024030602086THA00100001_12_page1_photo8.jpg",
#             "metadata": {
#               "dimensions_str": "741 x 730",
#               "size_bytes": 121453
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo8.jpg",
#             "rank": 2,
#             "similarity_score": 0.5065967440605164
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602077THA00100001_12.tif\\rank_003_N2024030602110THA00100001_12_page1_photo3.jpg",
#             "metadata": {
#               "dimensions_str": "545 x 863",
#               "size_bytes": 104811
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602110THA00100001_12_page1_photo3.jpg",
#             "rank": 3,
#             "similarity_score": 0.49728870391845703
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602077THA00100001_12.tif\\rank_004_N2024030602086THA00100001_12_page1_photo3.jpg",
#             "metadata": {
#               "dimensions_str": "738 x 330",
#               "size_bytes": 56867
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602086THA00100001_12_page1_photo3.jpg",
#             "rank": 4,
#             "similarity_score": 0.48426640033721924
#           },
#           {
#             "copied_to": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\admin\\api_runs\\api_run_07d0a92bda21\\N2024030602077THA00100001_12.tif\\rank_005_N2024030602110THA00100001_12_page1_photo2.jpg",
#             "metadata": {
#               "dimensions_str": "202 x 241",
#               "size_bytes": 9058
#             },
#             "original_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602110THA00100001_12_page1_photo2.jpg",
#             "rank": 5,
#             "similarity_score": 0.4531239867210388
#           }
#         ],
#         "results_summary": {
#           "number_of_similar_images_found": 5,
#           "search_statistics": {
#             "missing_result_files": 0
#           }
#         },
#         "search_parameters_overview": {
#           "feature_dimension_used": 2048,
#           "model_name_used": "resnet",
#           "search_method_used": "FaissIndex",
#           "top_k_requested": 5
#         },
#         "search_run_timestamp": "2025-08-22T14:17:44.341214"
#       }
#     ],
#     "total_queries_attempted": 3,
#     "total_queries_failed": 0,
#     "total_queries_successful": 3
#   },
#   "status": "success"
# }

# %% [markdown]
# ### 📑 TIF Document Search (Server-side Folder) — POST /search_with_tif (JSON)
# Performs OCR-based TIF document similarity search.

# %%
if exists_dir(SERVER_TIF_FOLDER):
    payload = {
        'config_overrides': {
            'search_task': {
                'input_tif_folder_for_search': SERVER_TIF_FOLDER,
                'top_k': 5,
                'top_doc': 3,
                'aggregation_strategy': 'max'
            }
        }
    }
    _ = call_api('POST', 'search_with_tif', json=payload)
else:
    print(f'⚠️ SERVER_TIF_FOLDER not found: {SERVER_TIF_FOLDER}. Skipping TIF search demo.')
# Out:
# ✅ POST http://127.0.0.1:5001/api/v1/search_with_tif -> 200
# {
#   "batch_search_gallery_path_segment": "cli_user/tif_doc_runs/20250822_141745",
#   "config_was_modified": false,
#   "exit_code": 0,
#   "fallback_to_bruteforce_message": null,
#   "general_search_summary_msg": "Batch TIF document search complete. Results in D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\cli_user\\tif_doc_runs\\20250822_141745",
#   "index_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_faiss_indices\\api_faiss_collection_resnet_flat.index",
#   "indexed_image_count": 102,
#   "last_search_was_batch": true,
#   "message": "Computed top 3 documents (global).",
#   "per_query": [
#     {
#       "aggregation_strategy_used": "max",
#       "elapsed_seconds": 0.3760865000076592,
#       "num_query_photos": 2,
#       "query_document": "N2024030602067THA00100001_12.tif",
#       "top_doc_used": 3,
#       "top_docs": [
#         {
#           "document": "N2024030602067THA00100001_12.tif",
#           "score": 0.9745608996599913
#         },
#         {
#           "document": "N2024030602086THA00100001_12.tif",
#           "score": 0.49635446071624756
#         },
#         {
#           "document": "N2024030602088THA00100001_12.tif",
#           "score": 0.4856411814689636
#         }
#       ],
#       "top_k_used": 5
#     },
#     {
#       "aggregation_strategy_used": "max",
#       "elapsed_seconds": 0.3032043999992311,
#       "num_query_photos": 2,
#       "query_document": "N2024030602067THA00100001_13.tif",
#       "top_doc_used": 3,
#       "top_docs": [
#         {
#           "document": "N2024030602067THA00100001_13.tif",
#           "score": 0.9376524612307549
#         },
#         {
#           "document": "N2024030602112THA00100001_13.tif",
#           "score": 0.5739215910434723
#         },
#         {
#           "document": "N2024030602077THA00100001_13.tif",
#           "score": 0.5503316819667816
#         }
#       ],
#       "top_k_used": 5
#     },
#     {
#       "aggregation_strategy_used": "max",
#       "elapsed_seconds": 0.2362864000024274,
#       "num_query_photos": 2,
#       "query_document": "N2024030602077THA00100001_12.tif",
#       "top_doc_used": 3,
#       "top_docs": [
#         {
#           "document": "N2024030602110THA00100001_12.tif",
#           "score": 0.6450450420379639
#         },
#         {
#           "document": "N2024030602086THA00100001_12.tif",
#           "score": 0.587450385093689
#         },
#         {
#           "document": "N2024030602077THA00100001_12.tif",
#           "score": 0.5516418814659119
#         }
#       ],
#       "top_k_used": 5
#     }
#   ],
#   "status": "success",
#   "tif_run_db_export_csv_path": null,
#   "tif_run_output_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\cli_user\\tif_doc_runs\\20250822_141745",
#   "tif_run_summary_json_path": "D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\api_search_results\\cli_user\\tif_doc_runs\\20250822_141745\\global_top\\search_results_summary.json",
#   "top_documents": [
#     {
#       "document": "N2024030602067THA00100001_12.tif",
#       "score": 0.9745608996599913
#     },
#     {
#       "document": "N2024030602067THA00100001_13.tif",
#       "score": 0.9376524612307549
#     },
#     {
#       "document": "N2024030602110THA00100001_12.tif",
#       "score": 0.6450450420379639
#     }
#   ]
# }

# %% [markdown]
# ### 📤 TIF Document Search (Client Upload) — POST /search_with_tif (multipart/form-data)
# Uploads one or more TIF files for a document similarity search.

# %%
valid_tifs = [p for p in LOCAL_TIF_FILES if exists_file(p)]
if valid_tifs:
    files = []
    for p in valid_tifs:
        files.append(('tif_file', (Path(p).name, open(p, 'rb'), 'application/octet-stream')))
    data = {
        'run_identifier': 'nb_tif_demo',
        'config_overrides': json.dumps({'search_task': {'top_k': 5, 'top_doc': 3}})
    }
    _ = call_api('POST', 'search_with_tif', files=files, data=data)
    for _, (_, fobj, _) in files:
        try: fobj.close()
        except Exception: pass
else:
    print('⚠️ No valid LOCAL_TIF_FILES found. Skipping client-side TIF upload demo.')
# Out:
# ⚠️ No valid LOCAL_TIF_FILES found. Skipping client-side TIF upload demo.

# %% [markdown]
# ### 🗂️ Browse Gallery — GET /gallery
# Fetches hierarchical listing of users, run types, and runs.

# %%
_ = call_api('GET', 'gallery')  # Root level (users)
# You can refine further, e.g., call_api('GET', 'gallery/your_username')
# Out:
# ✅ GET http://127.0.0.1:5001/api/v1/gallery -> 200
# {
#   "title": "Gallery - All Users",
#   "users": [
#     {
#       "link": "/gallery/admin",
#       "name": "admin"
#     },
#     {
#       "link": "/gallery/cli_user",
#       "name": "cli_user"
#     }
#   ],
#   "view_type": "user_level"
# }

# %% [markdown]
# ---
# # 🔄 Toggle Security from Notebook
# Set `DISABLE_API_SECURITY` and re-apply. Subsequent requests reflect the change immediately.

# %%
# Example: Disable security temporarily
DISABLE_API_SECURITY = True
set_disable_api_security(DISABLE_API_SECURITY)
# Now try calling status without Authorization header
_ = call_api('GET', 'status')

# Re-enable security if desired
# DISABLE_API_SECURITY = False
# set_disable_api_security(DISABLE_API_SECURITY)
# Out:
# Updated disable_api_security to True in d:\jk\jk_SMART_VISION\TEST_SRC\TifDoc_nd_image_similarity_search\api_server\configs\api_config.yaml
# ✅ GET http://127.0.0.1:5001/api/v1/status -> 200
# {
#   "active_model": "resnet",
#   "active_vector_db": "faiss",
#   "api_status": "operational",
#   "feature_extractor_status": "ok (model: 'resnet', dim: 2048)",
#   "system_name": "JK Image Similarity System API",
#   "timestamp": "2025-08-22T14:17:55.635513Z",
#   "vector_db_status": "not_ready (items: 0)"
# }

# %% [markdown]
# ---
# # 🖥️ CLI Demonstration (find_sim_images.py)
# The following cells demonstrate the core CLI for direct engine usage (outside the API).
#
# > Adjust paths as needed before running.

# %%
def run_cli(cmd_args):
    print('> Running:', ' '.join(cmd_args))
    res = subprocess.run(cmd_args, cwd=str(PROJECT_ROOT), capture_output=True, text=True)
    print('--- STDOUT ---')
    print(res.stdout)
    print('--- STDERR ---')
    print(res.stderr)
    if res.returncode != 0:
        print(f'Command failed with exit code {res.returncode}')
    return res

# Build index (CLI)
run_cli([sys.executable, 'find_sim_images.py', '--action', 'build_index', '--config-path', 'configs/image_similarity_config.yaml'])
# Out:
# > Running: c:\ProgramData\anaconda3\envs\image-similarity-env\python.exe find_sim_images.py --action build_index --config-path configs/image_similarity_config.yaml
# --- STDOUT ---
# Executing standard action: build_index
# {'status': 'error', 'exit_code': 1, 'message': 'No valid query specified.', 'error_details': 'No valid query specified.', 'config_was_modified': False, 'overall_results_output_path': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\search_results\\default_user\\searches\\20250822_141807', 'search_operation_summary': None, 'search_method_used': 'Error', 'model_name_used': 'efficientnet', 'query_image_path_processed': None, 'batch_folder_processed': None, 'indexed_image_count': 122, 'index_path': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\faiss_indices\\faiss_collection_efficientnet_flat.index'}
#
# --- STDERR ---
#
# Main Indexing:   0%|          | 0/1 [00:00<?, ?batch/s]
# Main Indexing: 100%|██████████| 1/1 [00:00<00:00, 12.08batch/s]
# CompletedProcess(args=['c:\\ProgramData\\anaconda3\\envs\\image-similarity-env\\python.exe', 'find_sim_images.py', '--action', 'build_index', '--config-path', 'configs/image_similarity_config.yaml'], returncode=0, stdout="Executing standard action: build_index\n{'status': 'error', 'exit_code': 1, 'message': 'No valid query specified.', 'error_details': 'No valid query specified.', 'config_was_modified': False, 'overall_results_output_path': 'D:\\\\jk\\\\jk_SMART_VISION\\\\TEST_SRC\\\\TifDoc_nd_image_similarity_search\\\\instance\\\\search_results\\\\default_user\\\\searches\\\\20250822_141807', 'search_operation_summary': None, 'search_method_used': 'Error', 'model_name_used': 'efficientnet', 'query_image_path_processed': None, 'batch_folder_processed': None, 'indexed_image_count': 122, 'index_path': 'D:\\\\jk\\\\jk_SMART_VISION\\\\TEST_SRC\\\\TifDoc_nd_image_similarity_search\\\\instance\\\\faiss_indices\\\\faiss_collection_efficientnet_flat.index'}\n", stderr='\nMain Indexing:   0%|          | 0/1 [00:00<?, ?batch/s]\nMain Indexing: 100%|██████████| 1/1 [00:00<00:00, 12.08batch/s]\n')

# %%
# Single image search (CLI)
if exists_file(SINGLE_QUERY_IMAGE):
    run_cli([
        sys.executable, 'find_sim_images.py',
        '--action', 'search',
        '--config-path', 'configs/image_similarity_config.yaml',
        '--query-image', SINGLE_QUERY_IMAGE
    ])
else:
    print(f'⚠️ SINGLE_QUERY_IMAGE not found: {SINGLE_QUERY_IMAGE}. Skipping CLI single search.')
# Out:
# > Running: c:\ProgramData\anaconda3\envs\image-similarity-env\python.exe find_sim_images.py --action search --config-path configs/image_similarity_config.yaml --query-image d:\jk\jk_SMART_VISION\TEST_SRC\TifDoc_nd_image_similarity_search\data_real\N2024030602067THA00100001_12.tif
# --- STDOUT ---
# Executing standard action: search
# {'status': 'success', 'exit_code': 0, 'message': 'Single image search completed successfully.', 'overall_results_output_path': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\search_results\\default_user\\searches\\20250822_141818', 'search_operation_summary': {'search_run_timestamp': '2025-08-22T14:18:18.154714', 'query_image_details': {'original_path': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\data_real\\N2024030602067THA00100001_12.tif', 'copied_to': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\search_results\\default_user\\searches\\20250822_141818\\_query_image_source\\N2024030602067THA00100001_12.tif', 'metadata': {'dimensions_str': '1652 x 2336', 'size_bytes': 1030035}}, 'search_parameters_overview': {'top_k_requested': 5, 'search_method_used': 'FaissIndex', 'model_name_used': 'efficientnet', 'feature_dimension_used': 1280}, 'performance_metrics': {'total_search_operation_time_seconds': 0.07308387756347656}, 'results_summary': {'number_of_similar_images_found': 5, 'search_statistics': {'missing_result_files': 0}}, 'results': [{'rank': 1, 'original_path': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_12.tif', 'copied_to': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\search_results\\default_user\\searches\\20250822_141818\\rank_001_N2024030602067THA00100001_12.tif', 'similarity_score': 1.0, 'metadata': {'dimensions_str': '1652 x 2336', 'size_bytes': 1030035}}, {'rank': 2, 'original_path': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_12_page1_photo1.jpg', 'copied_to': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\search_results\\default_user\\searches\\20250822_141818\\rank_002_N2024030602067THA00100001_12_page1_photo1.jpg', 'similarity_score': 0.5759186744689941, 'metadata': {'dimensions_str': '1309 x 864', 'size_bytes': 139832}}, {'rank': 3, 'original_path': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602067THA00100001_12_page1_photo0.jpg', 'copied_to': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\search_results\\default_user\\searches\\20250822_141818\\rank_003_N2024030602067THA00100001_12_page1_photo0.jpg', 'similarity_score': 0.5061747431755066, 'metadata': {'dimensions_str': '1309 x 864', 'size_bytes': 268469}}, {'rank': 4, 'original_path': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602125THA00100001_12_page1_photo5.jpg', 'copied_to': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\search_results\\default_user\\searches\\20250822_141818\\rank_004_N2024030602125THA00100001_12_page1_photo5.jpg', 'similarity_score': 0.40215039253234863, 'metadata': {'dimensions_str': '1014 x 509', 'size_bytes': 79861}}, {'rank': 5, 'original_path': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\database_images\\N2024030602100THA00100001_13_page1_photo3.jpg', 'copied_to': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\search_results\\default_user\\searches\\20250822_141818\\rank_005_N2024030602100THA00100001_13_page1_photo3.jpg', 'similarity_score': 0.3633286952972412, 'metadata': {'dimensions_str': '1315 x 203', 'size_bytes': 47559}}]}, 'search_method_used': 'faiss', 'model_name_used': 'efficientnet', 'config_was_modified': False, 'indexed_image_count': 122, 'index_path': 'D:\\jk\\jk_SMART_VISION\\TEST_SRC\\TifDoc_nd_image_similarity_search\\instance\\faiss_indices\\faiss_collection_efficientnet_flat.index', 'fallback_to_bruteforce_message': None}
#
# --- STDERR ---

# %%
# TIF document search (CLI)
if exists_dir(SERVER_TIF_FOLDER):
    run_cli([
        sys.executable, 'find_sim_images.py',
        '--action', 'search_with_tif',
        '--config-path', 'configs/image_similarity_config.yaml',
        '--input-tif-folder-for-search', SERVER_TIF_FOLDER,
        '--top-k', '5',
        '--top-doc','3',
        '--aggregation-strategy', 'max'
    ])
else:
    print(f'⚠️ SERVER_TIF_FOLDER not found: {SERVER_TIF_FOLDER}. Skipping CLI TIF search.')
# Out:
# > Running: c:\ProgramData\anaconda3\envs\image-similarity-env\python.exe find_sim_images.py --action search_with_tif --config-path configs/image_similarity_config.yaml --input-tif-folder-for-search d:\jk\jk_SMART_VISION\TEST_SRC\TifDoc_nd_image_similarity_search\data_real --top-k 5 --top-doc 3 --aggregation-strategy max
# --- STDOUT ---
# Executing new action: Search with TIFs
# --- 🚀 OCR ENGINE INITIALIZATION (PaddleOCR) ---
#   - INFO: Mapped language code 'ko' to 'korean' for PaddleOCR compatibility via config.
#
# 🔎 Checking for PaddleOCR models...
#   - Resolved Detection path: C:\Users\jeeb\.paddlex\official_models\PP-OCRv3_det\Multilingual_PP-OCRv3_det_infer
#   - Resolved Recognition path: C:\Users\jeeb\.paddlex\official_models\korean_PP-OCRv3_rec\korean_PP-OCRv3_rec_infer
# - INFO: Model 'Classification' not resolved in provided path. Will use PaddleOCR default models (auto-download or cached).
#
# 🔧 Assembling PaddleOCR Parameters:
#   - Language: 'korean'
#   - GPU Acceleration: Enabled
#   - Text Angle Classification: Enabled
#
# ⚙️ Initializing PaddleOCR engine with parameters:
#   - use_angle_cls: True
#   - lang: korean
#   - det_model_dir: C:\Users\jeeb\.paddlex\official_models\PP-OCRv3_det\Multilingual_PP-OCRv3_det_infer
#   - rec_model_dir: C:\Users\jeeb\.paddlex\official_models\korean_PP-OCRv3_rec\korean_PP-OCRv3_rec_infer
#   - rec_batch_num: 6
#   - show_log: False
# [2025/08/22 14:34:39] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/08/22 14:34:43] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
# [2025/08/22 14:34:44] ppocr WARNING: The first GPU is used for inference by default, GPU ID: 0
#   - INFO: PaddleOCR resolved Classification model directory to: C:\Users\jeeb\.paddleocr\whl\cls\ch_ppocr_mobile_v2.0_cls_infer
#   - INFO: PaddleOCR resolved Classification model directory to: C:\Users\jeeb\.paddleocr\whl\cls\ch_ppocr_mobile_v2.0_cls_infer
# CONSOLE DEBUG: N2024030602067THA00100001_12.tif p1: crops=2
# CONSOLE DEBUG: TIF 'N2024030602067THA00100001_12.tif': extracted 2 photo(s).
# CONSOLE DEBUG: N2024030602067THA00100001_13.tif p1: crops=2
# CONSOLE DEBUG: TIF 'N2024030602067THA00100001_13.tif': extracted 2 photo(s).
# CONSOLE DEBUG: N2024030602077THA00100001_12.tif p1: crops=2
# CONSOLE DEBUG: TIF 'N2024030602077THA00100001_12.tif': extracted 2 photo(s).
# CONSOLE DEBUG: N2024030602067THA00100001_12.tif total crops=2
# CONSOLE DEBUG: N2024030602067THA00100001_13.tif total crops=2
# CONSOLE DEBUG: N2024030602077THA00100001_12.tif total crops=2
# CONSOLE DEBUG: Total crops across batch: 6
#
# === Global Top Documents ===
# 01. N2024030602067THA00100001_12.tif  score=0.9713
# 02. N2024030602067THA00100001_13.tif  score=0.9545
# 03. N2024030602077THA00100001_12.tif  score=0.5929
#
# === Per-Query Results ===
# Query: N2024030602067THA00100001_12.tif  photos=2  agg=max  t=0.404s
#    01. N2024030602067THA00100001_12.tif  score=0.9713
#    02. N2024030602104THA00100001_12.tif  score=0.4774
#    03. N2024030602125THA00100001_12.tif  score=0.4515
# Query: N2024030602067THA00100001_13.tif  photos=2  agg=max  t=0.296s
#    01. N2024030602067THA00100001_13.tif  score=0.9545
#    02. N2024030602091THA00100001_13.tif  score=0.4408
#    03. N2024030602110THA00100001_13.tif  score=0.4369
# Query: N2024030602077THA00100001_12.tif  photos=2  agg=max  t=0.282s
#    01. N2024030602077THA00100001_12.tif  score=0.5929
#    02. N2024030602086THA00100001_12.tif  score=0.5470
#    03. N2024030602110THA00100001_12.tif  score=0.5190
#
# Run output folder: D:\jk\jk_SMART_VISION\TEST_SRC\TifDoc_nd_image_similarity_search\instance\search_results\cli_user\tif_doc_runs\20250822_143436
# Summary JSON: D:\jk\jk_SMART_VISION\TEST_SRC\TifDoc_nd_image_similarity_search\instance\search_results\cli_user\tif_doc_runs\20250822_143436\global_top\search_results_summary.json
#
# --- STDERR ---
#
# Batch Searching TIFs:   0%|          | 0/3 [00:00<?, ?it/s][2025-08-22 14:34:46,642] [ WARNING] workflow.py:983 - Parent TIF 'N2024030602104THA00100001_12.tif' not found in configured folders. Skipping copy.
# [2025-08-22 14:34:46,643] [ WARNING] workflow.py:983 - Parent TIF 'N2024030602125THA00100001_12.tif' not found in configured folders. Skipping copy.
#
# Batch Searching TIFs:  33%|███▎      | 1/3 [00:00<00:00,  2.43it/s][2025-08-22 14:34:46,940] [ WARNING] workflow.py:983 - Parent TIF 'N2024030602091THA00100001_13.tif' not found in configured folders. Skipping copy.
# [2025-08-22 14:34:46,940] [ WARNING] workflow.py:983 - Parent TIF 'N2024030602110THA00100001_13.tif' not found in configured folders. Skipping copy.
#
# Batch Searching TIFs:  67%|██████▋   | 2/3 [00:00<00:00,  2.91it/s][2025-08-22 14:34:47,225] [ WARNING] workflow.py:983 - Parent TIF 'N2024030602086THA00100001_12.tif' not found in configured folders. Skipping copy.
# [2025-08-22 14:34:47,232] [ WARNING] workflow.py:983 - Parent TIF 'N2024030602110THA00100001_12.tif' not found in configured folders. Skipping copy.
#
# Batch Searching TIFs: 100%|██████████| 3/3 [00:00<00:00,  3.13it/s]
# Batch Searching TIFs: 100%|██████████| 3/3 [00:00<00:00,  3.00it/s]
